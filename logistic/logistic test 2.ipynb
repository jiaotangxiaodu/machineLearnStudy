# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import sys
sys.path.insert(1, "/Users/saiwei/PycharmProjects/linear_regression/LinearRegression")

# %%
from Regression import LogisticRegression

# %%
X = np.random.uniform(low=0,high=1,size=1000).reshape([-1,5])

# %%
y = np.array(X_mean > 0.5,dtype='int')

# %%
X = X +np.random.normal(0,0.1,1000).reshape([-1,5])

# %%
from sklearn.decomposition import PCA
pca = PCA()
PCA?
plt.scatter(np.array(range(0,200))[y==0],X_mean[y==0],c='r')
plt.scatter(np.array(range(0,200))[y==1],X_mean[y==1],c='b')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_mean.reshape(-1,1),y)

# %%
logistic_reg = LogisticRegression()

# %%
logistic_reg.fit(X_train,y_train,eta=0.1,epsilon=1e-5)
# Out:
# theta=[-0.002       0.00270149],j=0.6930342641807661,itr=0,dj=0.00011291637917931752
# theta=[-0.00398414  0.00540997],j=0.6929215987216395,itr=1,dj=0.00011266545912658188
# theta=[-0.00595291  0.00812519],j=0.6928091727244864,itr=2,dj=0.00011242599715310941
# theta=[-0.00790676  0.01084691],j=0.6926969754384089,itr=3,dj=0.00011219728607747559
# theta=[-0.00984617  0.01357489],j=0.6925849967758996,itr=4,dj=0.00011197866250933775
# theta=[-0.01177157  0.01630892],j=0.6924732272717595,itr=5,dj=0.00011176950414004683
# theta=[-0.01368339  0.01904877],j=0.6923616580445616,itr=6,dj=0.00011156922719790519
# theta=[-0.01558203  0.02179424],j=0.6922502807604982,itr=7,dj=0.00011137728406340752
# theta=[-0.01746791  0.02454511],j=0.6921390875994675,itr=8,dj=0.0001111931610306982
# theta=[-0.0193414  0.0273012],j=0.6920280712232594,itr=9,dj=0.00011101637620813953
# theta=[-0.02120288  0.0300623 ],j=0.6919172247457117,itr=10,dj=0.00011084647754766586
# ...

# %%
# Out:
# (200, 5)

# %%
()
# Out:
# 29
