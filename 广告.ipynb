# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
vals = [
    0.207837,
0.217819,
0.418814,
0.264625,
0.824940,
0.205337,
0.270447,
0.157482,
0.170610,
0.200947,
0.154378,
0.413548,
0.296249,
0.217398,
0.341407,
0.166941,
0.200370,
0.242458,
0.360561,
0.426168,
0.551746,
0.352352,
0.247718,
1.019737,
0.266475,
1.127952,
0.606904,
0.851259
]

# %%
acos_dict = (i,vals[i]) for i in len(vals)
# Out:
#   File "<ipython-input-4-202e730bd3ff>", line 1
#     acos_dict = (i,vals[i]) for i in len(vals)
#                               ^
# SyntaxError: invalid syntax

# %%
acos_dict = (i,vals[i]) for i in 0 to len(vals)
# Out:
#   File "<ipython-input-5-a7b1f4cc636e>", line 1
#     acos_dict = (i,vals[i]) for i in 0 to len(vals)
#                               ^
# SyntaxError: invalid syntax

# %%
0 to len(vals)
# Out:
#   File "<ipython-input-6-ac4220c89184>", line 1
#     0 to len(vals)
#        ^
# SyntaxError: invalid syntax

# %%
i for i in 0 to len(vals)
# Out:
#   File "<ipython-input-7-ab02cc94e053>", line 1
#     i for i in 0 to len(vals)
#         ^
# SyntaxError: invalid syntax

# %%
range(vals)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-4609d9a7a188> in <module>
# ----> 1 range(vals)
#
# TypeError: 'list' object cannot be interpreted as an integer

# %%
vals(len(vals))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-1a8edee3961e> in <module>
# ----> 1 vals(len(vals))
#
# TypeError: 'list' object is not callable

# %%
range(len(vals))
# Out:
# range(0, 28)

# %%
i for i in range(len(vals))
# Out:
#   File "<ipython-input-11-487d174bf4b4>", line 1
#     i for i in range(len(vals))
#         ^
# SyntaxError: invalid syntax

# %%
temp = i*1 for i in range(len(vals))
# Out:
#   File "<ipython-input-12-5b50a98bf659>", line 1
#     temp = i*1 for i in range(len(vals))
#                  ^
# SyntaxError: invalid syntax

# %%
[(i,vals[i]) for i in vals]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-55ec5d328e4d> in <module>
# ----> 1 [(i,vals[i]) for i in vals]
#
# <ipython-input-13-55ec5d328e4d> in <listcomp>(.0)
# ----> 1 [(i,vals[i]) for i in vals]
#
# TypeError: list indices must be integers or slices, not float

# %%
[(i,vals[i]) for i in range(len(vals))]
# Out:
# [(0, 0.207837),
#  (1, 0.217819),
#  (2, 0.418814),
#  (3, 0.264625),
#  (4, 0.82494),
#  (5, 0.205337),
#  (6, 0.270447),
#  (7, 0.157482),
#  (8, 0.17061),
#  (9, 0.200947),
#  (10, 0.154378),
#  (11, 0.413548),
#  (12, 0.296249),
#  (13, 0.217398),
#  (14, 0.341407),
#  (15, 0.166941),
#  (16, 0.20037),
#  (17, 0.242458),
#  (18, 0.360561),
#  (19, 0.426168),
#  (20, 0.551746),
#  (21, 0.352352),
#  (22, 0.247718),
#  (23, 1.019737),
#  (24, 0.266475),
#  (25, 1.127952),
#  (26, 0.606904),
#  (27, 0.851259)]

# %%
acos_dict = _

# %%
plt?

# %%
plt.plot(acos_dict)

# %%
plt.vals
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-c4b8ba335f67> in <module>
# ----> 1 plt.vals
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'vals'

# %%
plt.plot(vals)

# %%
temp = (0,None),
(29.88,0.191563),
(25.82,0.339782),
(0,None),
(28.44,0.374260),
(34.87,0.435929),
(25.48,0.167654),
(40.90,0.538229),
(30.90,0.203316),
(58.43,0.384458),
(32.62,0.429267),
(40.54,0.533491),
(45.97,0.604948),
(0,None),
(0,None),
(74.28,0.137573),
(65.12,0.243021),
(66.76,0.219634),
(50.01,0.107794),
(44.44,0.109205),
(44.61,1.652834),
(41.85,0.124944),
(53.27,0.350507),
(68.57,0.180471),
(151.70,0.499079),
(27.80,0.365838),
(50.56,0.332675),
(53.56,0.299268)
# Out:
# (53.56, 0.299268)

# %%
temp = [(0,None),
(29.88,0.191563),
(25.82,0.339782),
(0,None),
(28.44,0.374260),
(34.87,0.435929),
(25.48,0.167654),
(40.90,0.538229),
(30.90,0.203316),
(58.43,0.384458),
(32.62,0.429267),
(40.54,0.533491),
(45.97,0.604948),
(0,None),
(0,None),
(74.28,0.137573),
(65.12,0.243021),
(66.76,0.219634),
(50.01,0.107794),
(44.44,0.109205),
(44.61,1.652834),
(41.85,0.124944),
(53.27,0.350507),
(68.57,0.180471),
(151.70,0.499079),
(27.80,0.365838),
(50.56,0.332675),
(53.56,0.299268)]

# %%
y1 = [it[0] for it in temp]
y2 = [it[1] for it in temp]

fig = plt.figure()

ax1 = fig.add_subplot(111)
ax1.plot(y1,'blue')
ax1.set_ylabel('costs($,blue)')
ax1.set_title("5051 last 30 days")

ax2 = ax1.twinx()  # this is the important function
ax2.plot(y2, 'r')
ax2.set_ylabel('acos(red)')

plt.show()

# %%
temp = [(91.91,0.196422),
(55.19,0.460032),
(60.96,0.508085),
(71.81,0.598566),
(0,None),
(62.85,0.314329),
(56.41,0.470162),
(91.46,0.256961),
(69.49,0.361984),
(76.34,0.636326),
(82.83,0.130265),
(47.62,0.595399),
(56.75,0.473035),
(51.21,0.673904),
(71.22,0.265786),
(75.30,1.882971),
(64.09,0.232261),
(67.94,0.435569),
(10.46,0.261565),
(80.88,0.749166),
(27.61,1.022971),
(35.95,0.443992),
(133.97,0.620461),
(103.39,0.547240),
(80.51,0.381673),
(86.09,1.594850),
(80.67,0.513953),
(78.15,0.413645)]

# %%
y1 = [it[0] for it in temp]
y2 = [it[1] for it in temp]

fig = plt.figure()

ax1 = fig.add_subplot(111)
ax1.plot(y1,'blue')
ax1.set_ylabel('costs($,blue)')
ax1.set_title("5052 last 30 days")
ax1.vlines(22,0,150)

ax2 = ax1.twinx()  # this is the important function
ax2.plot(y2, 'r')
ax2.set_ylabel('acos(red)')

plt.show()

# %%
temp=[(68.99,0.627638),
(68.32,0.390690),
(69.84,0.529492),
(64.88,0.713516),
(61.56,0.677004),
(62.47,0.687012),
(61.47,0.530280),
(61.05,1.566590),
(62.01,0.397806),
(59.06,0.532456),
(65.57,0.437454),
(66.72,0.538455),
(63.62,0.979523),
(62.81,0.604407),
(63.09,0.809469),
(61.96,0.314725),
(63.99,0.653426),
(24.43,0.531434),
(68.53,1.055119),
(67.61,0.845654),
(55.67,0.612229),
(56.32,0.476279),
(47.23,0.397158),
(69.89,0.486835),
(42.07,0.921779),
(34.63,1.332948),
(40.52,0.362012),
(25.65,0.647074)]

# %%
y1 = [it[0] for it in temp]
y2 = [it[1] for it in temp]

fig = plt.figure()

ax1 = fig.add_subplot(111)
ax1.plot(y1,'blue')
ax1.set_ylabel('costs($,blue)')
ax1.set_title("7203 last 30 days")
ax1.vlines(22,0,150)

ax2 = ax1.twinx()  # this is the important function
ax2.plot(y2, 'r')
ax2.set_ylabel('acos(red)')

plt.show()

# %%
temp=[(79.14,0.207837),
(77.06,0.217819),
(55.25,0.418814),
(58.58,0.264625),
(51.93,0.824940),
(46.17,0.205337),
(40.54,0.270447),
(59.41,0.157482),
(64.11,0.170610),
(89.16,0.200947),
(77.22,0.154378),
(68.19,0.413548),
(57.73,0.296249),
(81.47,0.217398),
(90.07,0.341407),
(61.98,0.166941),
(47.66,0.200370),
(65.42,0.242458),
(52.97,0.360561),
(78.79,0.426168),
(112.49,0.551746),
(146.73,0.352352),
(129.18,0.247718),
(110.05,1.019737),
(101.86,0.266475),
(84.54,1.127952),
(81.58,0.606904),
(65.93,0.851259)]

# %%
y1 = [it[0] for it in temp]
y2 = [it[1] for it in temp]

fig = plt.figure()

ax1 = fig.add_subplot(111)
ax1.plot(y1,'blue')
ax1.set_ylabel('costs($,blue)')
ax1.set_title("6150 last 30 days")
ax1.vlines(22,0,150)

ax2 = ax1.twinx()  # this is the important function
ax2.plot(y2, 'r')
ax2.set_ylabel('acos(red)')


plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

temp=[(68.99,0.627638),
(68.32,0.390690),
(69.84,0.529492),
(64.88,0.713516),
(61.56,0.677004),
(62.47,0.687012),
(61.47,0.530280),
(61.05,1.566590),
(62.01,0.397806),
(59.06,0.532456),
(65.57,0.437454),
(66.72,0.538455),
(63.62,0.979523),
(62.81,0.604407),
(63.09,0.809469),
(61.96,0.314725),
(63.99,0.653426),
(24.43,0.531434),
(68.53,1.055119),
(67.61,0.845654),
(55.67,0.612229),
(56.32,0.476279),
(47.23,0.397158),
(68.70,0.478546),
(42.07,0.587406),
(34.63,0.666474),
(40.52,0.324368),
(30.08,0.458397),
(32.29,1.242879),
(18.23,0.701694),
(29.29,0.450962),
(24.88,0.478830),
(15.28,1.176289),
(23.41,0.353145),
(None,None),
(36.03,0.908930),
(22.02,0.408004),
(16.48,0.317167),
(13.99,0.180237),]

y1 = [it[0] for it in temp]
y2 = [it[1] for it in temp]

fig = plt.figure()

ax1 = fig.add_subplot(111)
ax1.plot(y1,'blue')
ax1.set_ylabel('costs($,blue)')
ax1.set_title("7203 last 30 days")
ax1.vlines(11,0,100)

ax2 = ax1.twinx()  # this is the important function
ax2.plot(y2, 'r')
ax2.set_ylabel('acos(red)')


plt.show()
